# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ls
# Out:
# 2011_US_AGRI_Exports                Plotly and Cufflink p-1.ipynb
# 2014_World_GDP                      Practice-1.ipynb
# Foodbudget.xlsx                     countries-of-the-world.zip
# Geoplot p-1.ipynb                   df1
# Geoplot.ipynb                       df2
# Pandas Excersise.ipynb              df3
# Pandas built in Data viz p-1.ipynb  temp-plot.html
# Pandas built in data viz 1.ipynb    world-bank-gdp-ranking.zip
# Plotly & Cufflinks 1.ipynb          world-happiness-report-2019.zip

# %%
df=pd.read_csv('world-happiness-report-2019.zip')

# %%
df
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# 5                 Switzerland       6            11             44.0
# 6                      Sweden       7            18             34.0
# 7                 New Zealand       8            15             22.0
# 8                      Canada       9            23             18.0
# 9                     Austria      10            10             64.0
# 10                  Australia      11            26             47.0
# 11                 Costa Rica      12            62              4.0
# 12                     Israel      13            14            104.0
# ...

# %%
df.plot(kind='scatter',x='Positive affect',y='Social support',s=10)

# %%
df.iplot(kind='scatter',x='Positive affect',y='Social support',mode='markers')
# Out:
# <div>
#
#
#             <div id="942bf0d3-efaf-4fa8-b099-63dd9f385e9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("942bf0d3-efaf-4fa8-b099-63dd9f385e9e")) {
#                     Plotly.newPlot(
#                         '942bf0d3-efaf-4fa8-b099-63dd9f385e9e',
# ...

# %%
df.iplot(kind='bar',x='Country (region)',y='Positive affect')
# Out:
# <div>
#
#
#             <div id="527f5a31-8604-402a-99bf-3fe91bdc84b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("527f5a31-8604-402a-99bf-3fe91bdc84b1")) {
#                     Plotly.newPlot(
#                         '527f5a31-8604-402a-99bf-3fe91bdc84b1',
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="7b89020b-b051-4278-9187-565bf99a508d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7b89020b-b051-4278-9187-565bf99a508d")) {
#                     Plotly.newPlot(
#                         '7b89020b-b051-4278-9187-565bf99a508d',
# ...

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c1db80c18>,
# ...
#       dtype=object)

# %%
df['Freedom'].hist()
