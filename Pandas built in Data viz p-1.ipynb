# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df3=pd.read_csv('df3')

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11682a4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11673c748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10498bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1049c72e8>]],
#       dtype=object)

# %%
df3['a'].hist()

# %%
plt.style.use('ggplot')
df3['a'].hist()

# %%
plt.style.use('bmh')
df3['a'].hist()

# %%
plt.style.use('dark_background')
df3['a'].hist()

# %%
plt.style.use('fivethirtyeight')
df3['a'].hist()

# %%
df3.plot.area()

# %%
df3.plot.area(alpha=0.5)

# %%
df3.plot.bar()

# %%
df3.plot(kind='bar')

# %%
df3.plot(stacked=True)

# %%
df3['a'].plot.hist()

# %%
df3.plot.hist()

# %%
df3.plot.scatter(x='a',y='b')

# %%
df3.plot.scatter(x='a',y='b',c='c',cmap='magma',s=50,figsize=(12,12))

# %%
df3.plot.scatter(x='a',y='b',s=df3['c']*100)

# %%
df3.plot.box()

# %%
df3['a'].plot.kde(lw=4,ls='--')

# %%
df3.plot(kind='kde')

# %%
df3.plot.density()

# %%
f=plt.figure()
df3.ix[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
